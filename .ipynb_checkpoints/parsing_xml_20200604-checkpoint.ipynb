# %% [markdown]
# <a href="https://colab.research.google.com/github/siliang625/text_mining_health/blob/master/parsing_xml_20200604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4
# !pip3 install fastprogress --upgrade   #tqdm
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple, https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple
# Requirement already satisfied: BeautifulSoup4 in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (4.9.1)
# Requirement already satisfied: soupsieve<2.0 in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (from BeautifulSoup4) (1.9.6)
# Requirement already satisfied: backports.functools-lru-cache; python_version < "3" in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (from soupsieve<2.0->BeautifulSoup4) (1.6.1)
# /bin/sh: pip3: command not found

# %%
# %matplotlib inline
import pandas as pd
import requests
from urllib.request import urlopen
from fastprogress.fastprogress import master_bar, progress_bar
from urllib.parse import quote
from bs4 import BeautifulSoup
import os
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-21a167de7ba1> in <module>
#       3 import requests
#       4 from urllib.request import urlopen
# ----> 5 from fastprogress.fastprogress import master_bar, progress_bar
#       6 from urllib.parse import quote
#       7 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'fastprogress'

# %%
from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
#logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logging.basicConfig(level=logging.DEBUG, datefmt='%I:%M:%S')
logger = logging.getLogger("Parsing_Data")
# logger = logging.getLogger("Parsing_Data")
# logger.setLevel(logging.DEBUG)

# %%
# global variables
base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
search_url = "esearch.fcgi?db=pubmed&term="    # not pmc
fetch_url = "efetch.fcgi?db=pmc"
application = "&tool=digital_public_health"
email = "&email=siliang.liu@alumni.ubc.ca"

# %% [markdown]
# # key words:

# %% [markdown]
# Loading in key words and taking a look:

# %%
path = "./search_term_1.csv"
search_terms_df = pd.read_csv(path, header=None, keep_default_na=False)
search_terms_df
# Out:
#                            0                       1
# 0        mhealth or m-health           public health
# 1        ehealth or e-health        health promotion
# 2            virtual health        health prevention
# 3             mobile health        health protection
# 4              online health           health policy
# 5      internet-based health     health determinants
# 6      computer-based health       health evaluation
# 7         health informatics        health economics
# 8               social media    public health ethics
# 9      predictive algorithms         risk assessment
# 10   artificial intelligence            epidemiology
# 11  machine learning methods        community health
# 12                  big data  emergency preparedness
# 13         electronic health      emergency response
# 14                      web*           health equity
# 15                    digit*          social justice
# 16              telemedicine     social determinants
# 17                                      surveillance

# %%
search_terms_c1 = search_terms_df.iloc[:,0]
search_terms_c2 = search_terms_df.iloc[:,1]

# %% [markdown]
# # Define search query
#
# Let's define the query: we will use OR operator to connect all terms in column 0, as well as column 1, and use AND operator to connect subquery of column 0 and column 1.
#
# Our final search query:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=(“mhealth” OR “m-health“ OR “ehealth“ OR “e-health“ OR “virtual health“ OR “mobile health“ OR “online health“ OR “internet-based health“ OR “computer-based health“ OR “health informatics“ OR “social media“ OR “predictive algorithms“ OR “artificial intelligence“ OR “machine learning methods“ OR “big data“ OR “electronic health“ OR “telemedicine“ OR “digit*” OR “web*”) AND (“public health“ OR “health promotion“ OR “health prevention“ OR “health+protection“ OR “health policy” OR “health determinants“ OR “health evaluation“ OR “health economics“ OR “public health ethics“ OR “risk assessment“ OR “epidemiology“ OR “community health“ OR “emergency preparedness“ OR “emergency response“ OR “health equity“ OR “social justice“ OR “social determinants“ OR “surveillance“) AND “last 20 years”[dp]
#
#
# Note: [dp] is a "Field Tag" helping to search specific fields of the PubMed, it refers to "date of pubishing"[1].

# %% [markdown]
# First, let's build the query

# %%
# def form_query_term(df):
#     '''
#     arg: df: dataframe containing a list of terms1 in single column
#     return:
#         array: containing processed search terms, eg: "mhealth[tw] OR m-health[tw] OR ehealth[tw]"
#     '''
#     query_arr = []
#     tag = "[tw]"

#     for term in df:
#         if term == "" or "*" in term:
#             continue
            
#         # eg: mhealth or m-health
#         if " or " in term:
#             or_terms = term.split(" or ")
#             for each in or_terms:
#                # query_string += each.rstrip().lstrip()
#                 query_arr.append(each.rstrip().lstrip().replace(" ", "+") + tag)
                
#         else:
#             query_arr.append(term.rstrip().lstrip().replace(" ", "+") + tag)
            
#     return query_arr

# %%
query_string = "(“mhealth” OR “m-health“ OR “ehealth“ OR “e-health“ OR “virtual health“ OR “mobile health“ OR “online health“ OR “internet-based health“ OR “computer-based health“ OR “health informatics“ OR “social media“ OR “predictive algorithms“ OR “artificial intelligence“ OR “machine learning methods“ OR “big data“ OR “electronic health“ OR “telemedicine“ OR “digit” OR “web”) AND (“public health“ OR “health promotion“ OR “health prevention“ OR “health+protection“ OR “health policy” OR “health determinants“ OR “health evaluation“ OR “health economics“ OR “public health ethics“ OR “risk assessment“ OR “epidemiology“ OR “community health“ OR “emergency preparedness“ OR “emergency response“ OR “health equity“ OR “social justice“ OR “social determinants“ OR “surveillance“) AND “last 20 years”[dp]"
# connector = " " + "OR" + " "
# query_arr_a = form_query_term(search_terms_c1)     
# query_arr_b = form_query_term(search_terms_c2) 
# query_string = "(" + connector.join(query_arr_a) + ")" + " AND " + "(" + connector.join(query_arr_b) + ")"
logger.debug(query_string)
# Out:
# DEBUG:Parsing_Data:(“mhealth” OR “m-health“ OR “ehealth“ OR “e-health“ OR “virtual health“ OR “mobile health“ OR “online health“ OR “internet-based health“ OR “computer-based health“ OR “health informatics“ OR “social media“ OR “predictive algorithms“ OR “artificial intelligence“ OR “machine learning methods“ OR “big data“ OR “electronic health“ OR “telemedicine“ OR “digit” OR “web”) AND (“public health“ OR “health promotion“ OR “health prevention“ OR “health+protection“ OR “health policy” OR “health determinants“ OR “health evaluation“ OR “health economics“ OR “public health ethics“ OR “risk assessment“ OR “epidemiology“ OR “community health“ OR “emergency preparedness“ OR “emergency response“ OR “health equity“ OR “social justice“ OR “social determinants“ OR “surveillance“) AND “last 20 years”[dp]

# %% [markdown]
# Secondly, Lets extract all the related ids givne the query

# %%
def extract_ids(query_term, return_size=10):
    '''
    args: query_string 
    return: find and set max_return_size 
            return list of related ids
    '''

    ret_max_term = "&RetMax=" + str(return_size)
    
    base_url_key_word = base_url + search_url + quote(query_term) + ret_max_term #+ application + email
    print(base_url_key_word)
    
    page_kw = urlopen(base_url_key_word)
    soup_kw = BeautifulSoup(page_kw, "xml")
    
    # get text form of everything in the xml file
    # soup_kw.get_text()
    
    return_size = soup_kw.find('Count').text
    #print(return_size)
    id_list = soup_kw.find_all('Id')
    
    return_ids = []
    for each_id in id_list:
        # print(each_id.text)
        return_ids.append(each_id.text)
    
    return return_size, return_ids

# %%
return_size = extract_ids(query_string)[0]
logger.debug("there are {} related papers".format(return_size))
return_ids = extract_ids(query_string, return_size)[1]

# save the pmc_list in a file:
f=open('./pmc_list.txt','w')
for id in return_ids:
    f.write(id+'\n')
f.close()
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=%28%E2%80%9Cmhealth%E2%80%9D%20OR%20%E2%80%9Cm-health%E2%80%9C%20OR%20%E2%80%9Cehealth%E2%80%9C%20OR%20%E2%80%9Ce-health%E2%80%9C%20OR%20%E2%80%9Cvirtual%20health%E2%80%9C%20OR%20%E2%80%9Cmobile%20health%E2%80%9C%20OR%20%E2%80%9Conline%20health%E2%80%9C%20OR%20%E2%80%9Cinternet-based%20health%E2%80%9C%20OR%20%E2%80%9Ccomputer-based%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20informatics%E2%80%9C%20OR%20%E2%80%9Csocial%20media%E2%80%9C%20OR%20%E2%80%9Cpredictive%20algorithms%E2%80%9C%20OR%20%E2%80%9Cartificial%20intelligence%E2%80%9C%20OR%20%E2%80%9Cmachine%20learning%20methods%E2%80%9C%20OR%20%E2%80%9Cbig%20data%E2%80%9C%20OR%20%E2%80%9Celectronic%20health%E2%80%9C%20OR%20%E2%80%9Ctelemedicine%E2%80%9C%20OR%20%E2%80%9Cdigit%E2%80%9D%20OR%20%E2%80%9Cweb%E2%80%9D%29%20AND%20%28%E2%80%9Cpublic%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20promotion%E2%80%9C%20OR%20%E2%80%9Chealth%20prevention%E2%80%9C%20OR%20%E2%80%9Chealth%2Bprotection%E2%80%9C%20OR%20%E2%80%9Chealth%20policy%E2%80%9D%20OR%20%E2%80%9Chealth%20determinants%E2%80%9C%20OR%20%E2%80%9Chealth%20evaluation%E2%80%9C%20OR%20%E2%80%9Chealth%20economics%E2%80%9C%20OR%20%E2%80%9Cpublic%20health%20ethics%E2%80%9C%20OR%20%E2%80%9Crisk%20assessment%E2%80%9C%20OR%20%E2%80%9Cepidemiology%E2%80%9C%20OR%20%E2%80%9Ccommunity%20health%E2%80%9C%20OR%20%E2%80%9Cemergency%20preparedness%E2%80%9C%20OR%20%E2%80%9Cemergency%20response%E2%80%9C%20OR%20%E2%80%9Chealth%20equity%E2%80%9C%20OR%20%E2%80%9Csocial%20justice%E2%80%9C%20OR%20%E2%80%9Csocial%20determinants%E2%80%9C%20OR%20%E2%80%9Csurveillance%E2%80%9C%29%20AND%20%E2%80%9Clast%2020%20years%E2%80%9D%5Bdp%5D&RetMax=10
# DEBUG:Parsing_Data:there are 61548 related papers
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=%28%E2%80%9Cmhealth%E2%80%9D%20OR%20%E2%80%9Cm-health%E2%80%9C%20OR%20%E2%80%9Cehealth%E2%80%9C%20OR%20%E2%80%9Ce-health%E2%80%9C%20OR%20%E2%80%9Cvirtual%20health%E2%80%9C%20OR%20%E2%80%9Cmobile%20health%E2%80%9C%20OR%20%E2%80%9Conline%20health%E2%80%9C%20OR%20%E2%80%9Cinternet-based%20health%E2%80%9C%20OR%20%E2%80%9Ccomputer-based%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20informatics%E2%80%9C%20OR%20%E2%80%9Csocial%20media%E2%80%9C%20OR%20%E2%80%9Cpredictive%20algorithms%E2%80%9C%20OR%20%E2%80%9Cartificial%20intelligence%E2%80%9C%20OR%20%E2%80%9Cmachine%20learning%20methods%E2%80%9C%20OR%20%E2%80%9Cbig%20data%E2%80%9C%20OR%20%E2%80%9Celectronic%20health%E2%80%9C%20OR%20%E2%80%9Ctelemedicine%E2%80%9C%20OR%20%E2%80%9Cdigit%E2%80%9D%20OR%20%E2%80%9Cweb%E2%80%9D%29%20AND%20%28%E2%80%9Cpublic%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20promotion%E2%80%9C%20OR%20%E2%80%9Chealth%20prevention%E2%80%9C%20OR%20%E2%80%9Chealth%2Bprotection%E2%80%9C%20OR%20%E2%80%9Chealth%20policy%E2%80%9D%20OR%20%E2%80%9Chealth%20determinants%E2%80%9C%20OR%20%E2%80%9Chealth%20evaluation%E2%80%9C%20OR%20%E2%80%9Chealth%20economics%E2%80%9C%20OR%20%E2%80%9Cpublic%20health%20ethics%E2%80%9C%20OR%20%E2%80%9Crisk%20assessment%E2%80%9C%20OR%20%E2%80%9Cepidemiology%E2%80%9C%20OR%20%E2%80%9Ccommunity%20health%E2%80%9C%20OR%20%E2%80%9Cemergency%20preparedness%E2%80%9C%20OR%20%E2%80%9Cemergency%20response%E2%80%9C%20OR%20%E2%80%9Chealth%20equity%E2%80%9C%20OR%20%E2%80%9Csocial%20justice%E2%80%9C%20OR%20%E2%80%9Csocial%20determinants%E2%80%9C%20OR%20%E2%80%9Csurveillance%E2%80%9C%29%20AND%20%E2%80%9Clast%2020%20years%E2%80%9D%5Bdp%5D&RetMax=61548

# %% [markdown]
# # Extract article information in xml

# %%
#!mkdir full_content

# %%
#sem = threading.Semaphore(3)

def extract_xml(paper_id):
    
    query_id = "&id=" + str(paper_id)
    base_url_content = base_url + fetch_url + query_id
    sem.acquire()
    try:
        response = requests.get(base_url_content)
        with open('./data/{}_paper.xml'.format(paper_id), 'wb') as file:
            file.write(response.content)
        file.close()
    finally:
        sem.release()
    

    # get text form of everything in the xml file
    #soup.get_text()
    
    time.sleep(1)

# %%
#for each_id in progress_bar(return_ids):
for each_id in return_ids:
    logger.debug("########" + each_id)
    extract_xml(each_id)
# Out:
# DEBUG:Parsing_Data:########32623740
# DEBUG:Parsing_Data:########32623682
# DEBUG:Parsing_Data:########32623474
# DEBUG:Parsing_Data:########32623436
# DEBUG:Parsing_Data:########32623330
# DEBUG:Parsing_Data:########32623222
# DEBUG:Parsing_Data:########32623083
# DEBUG:Parsing_Data:########32622896
# DEBUG:Parsing_Data:########32533537
# DEBUG:Parsing_Data:########32533365
# DEBUG:Parsing_Data:########32533174
# DEBUG:Parsing_Data:########32532945
# DEBUG:Parsing_Data:########32532938
# DEBUG:Parsing_Data:########32532936
# DEBUG:Parsing_Data:########32532934
# DEBUG:Parsing_Data:########32532824
# DEBUG:Parsing_Data:########32532814
# DEBUG:Parsing_Data:########32532785
# DEBUG:Parsing_Data:########32532782
# DEBUG:Parsing_Data:########32532778
# DEBUG:Parsing_Data:########32532760
# DEBUG:Parsing_Data:########32532543
# DEBUG:Parsing_Data:########32532222
# DEBUG:Parsing_Data:########32532213
# DEBUG:Parsing_Data:########32532212
# DEBUG:Parsing_Data:########32532096
# DEBUG:Parsing_Data:########32532077
# DEBUG:Parsing_Data:########32532050
# DEBUG:Parsing_Data:########32531892
# DEBUG:Parsing_Data:########32531888
# DEBUG:Parsing_Data:########32531869
# DEBUG:Parsing_Data:########32531719
# DEBUG:Parsing_Data:########32531405
# DEBUG:Parsing_Data:########32531046
# DEBUG:Parsing_Data:########32530915
# DEBUG:Parsing_Data:########32530855
# DEBUG:Parsing_Data:########32530828
# DEBUG:Parsing_Data:########32530818
# DEBUG:Parsing_Data:########32530817
# DEBUG:Parsing_Data:########32530773
# DEBUG:Parsing_Data:########32530747
# DEBUG:Parsing_Data:########32530435
# DEBUG:Parsing_Data:########32530424
# DEBUG:Parsing_Data:########32530421
# DEBUG:Parsing_Data:########32529974
# DEBUG:Parsing_Data:########32529927
# DEBUG:Parsing_Data:########32529820
# DEBUG:Parsing_Data:########32529792
# DEBUG:Parsing_Data:########32529761
# DEBUG:Parsing_Data:########32529586
# DEBUG:Parsing_Data:########32529578
# DEBUG:Parsing_Data:########32529512
# DEBUG:Parsing_Data:########32529261
# DEBUG:Parsing_Data:########32529044
# DEBUG:Parsing_Data:########32529034
# DEBUG:Parsing_Data:########32528920
# DEBUG:Parsing_Data:########32528665
# DEBUG:Parsing_Data:########32528613
# DEBUG:Parsing_Data:########32527797
# DEBUG:Parsing_Data:########32527637
# DEBUG:Parsing_Data:########32527391
# DEBUG:Parsing_Data:########32527322
# DEBUG:Parsing_Data:########32527314
# DEBUG:Parsing_Data:########32527251
# DEBUG:Parsing_Data:########32527248
# DEBUG:Parsing_Data:########32527164
# DEBUG:Parsing_Data:########32527152
# DEBUG:Parsing_Data:########32526871
# DEBUG:Parsing_Data:########32526532
# DEBUG:Parsing_Data:########32525983
# DEBUG:Parsing_Data:########32525977
# DEBUG:Parsing_Data:########32525811
# DEBUG:Parsing_Data:########32525606
# DEBUG:Parsing_Data:########32525511
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-79c73ec14daf> in <module>
#       2 for each_id in return_ids:
#       3     logger.debug("########" + each_id)
# ----> 4     extract_xml(each_id)
#       5
#
# <ipython-input-29-e8952f44d89c> in extract_xml(paper_id)
#      12     #soup.get_text()
#      13
# ---> 14     time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# # TODO
#
# - how to treat sesarch terms, such as :"mhealth or m-health" and "web*"

# %% [markdown]
# # Reference
#
# [1]Search Field Tags:  https://www.nlm.nih.gov/bsd/disted/pubmedtutorial/020_710.html
