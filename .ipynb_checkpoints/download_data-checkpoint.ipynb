# %%
# !pip install BeautifulSoup4
# !pip install fastprogress  #tqdm
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple, https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple
# Requirement already satisfied: BeautifulSoup4 in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (4.9.1)
# Requirement already satisfied: soupsieve<2.0 in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (from BeautifulSoup4) (1.9.6)
# Requirement already satisfied: backports.functools-lru-cache; python_version < "3" in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (from soupsieve<2.0->BeautifulSoup4) (1.6.1)
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple, https://celine.liu:****@artifactory.hootops.com/artifactory/api/pypi/hootsuite-pypi/simple
# Requirement already satisfied: fastprogress in /Users/celine.liu/Library/Python/2.7/lib/python/site-packages (0.1.22)

# %%
# %matplotlib inline
import pandas as pd
import requests
from urllib.request import urlopen
#from fastprogress.fastprogress import master_bar, progress_bar
from urllib.parse import quote
from bs4 import BeautifulSoup
import os
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-21a167de7ba1> in <module>
#       3 import requests
#       4 from urllib.request import urlopen
# ----> 5 from fastprogress.fastprogress import master_bar, progress_bar
#       6 from urllib.parse import quote
#       7 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'fastprogress'

# %%
from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
#logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logging.basicConfig(level=logging.DEBUG, datefmt='%I:%M:%S')
logger = logging.getLogger("Parsing_Data")
# logger = logging.getLogger("Parsing_Data")
# logger.setLevel(logging.DEBUG)

# %%
# global variables
base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
search_url = "esearch.fcgi?db=pubmed&term="
fetch_url = "efetch.fcgi?db=pmc"
application = "&tool=digital_public_health"
email = "&email=siliang.liu@alumni.ubc.ca"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#!pwd
# %cd '/content/drive/My Drive/[JOB] RA'
#!mkdir data
# Out:
# /content/drive/My Drive/[JOB] RA

# %%
# !ls |wc -l
# Out:
# ls: cannot open directory '.': Input/output error
# 0

# %%
from pathlib import Path
count = 0
for path in Path('data').glob('*.xml'):
    count += 1
count
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-331a2a11c4f1> in <module>()
#       1 from pathlib import Path
#       2 count = 0
# ----> 3 for path in Path('data').glob('*.xml'):
#       4     count += 1
#       5 count
#
# /usr/lib/python3.6/pathlib.py in glob(self, pattern)
#    1098             raise NotImplementedError("Non-relative patterns are unsupported")
#    1099         selector = _make_selector(tuple(pattern_parts))
# -> 1100         for p in selector.select_from(self):
#    1101             yield p
#    1102
#
# /usr/lib/python3.6/pathlib.py in _select_from(self, parent_path, is_dir, exists, scandir)
#     521         try:
#     522             cf = parent_path._flavour.casefold
# --> 523             entries = list(scandir(parent_path))
#     524             for entry in entries:
#     525                 if not self.dironly or entry.is_dir():
#
# /usr/lib/python3.6/pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# OSError: [Errno 5] Input/output error: 'data'

# %% [markdown]
# # key words:

# %% [markdown]
# Loading in key words and taking a look:

# %%
path = "./search_term_1.csv"
search_terms_df = pd.read_csv(path, header=None, keep_default_na=False)
search_terms_df
# Out:
#                            0                       1
# 0        mhealth or m-health           public health
# 1        ehealth or e-health        health promotion
# 2            virtual health        health prevention
# 3             mobile health        health protection
# 4              online health           health policy
# 5      internet-based health     health determinants
# 6      computer-based health       health evaluation
# 7         health informatics        health economics
# 8               social media    public health ethics
# 9      predictive algorithms         risk assessment
# 10   artificial intelligence            epidemiology
# 11  machine learning methods        community health
# 12                  big data  emergency preparedness
# 13         electronic health      emergency response
# 14                      web*           health equity
# 15                    digit*          social justice
# 16              telemedicine     social determinants
# 17                                      surveillance

# %%
search_terms_c1 = search_terms_df.iloc[:,0]
search_terms_c2 = search_terms_df.iloc[:,1]

# %% [markdown]
# # Define search query
#
# Let's define the query: we will use OR operator to connect all terms in column 0, as well as column 1, and use AND operator to connect subquery of column 0 and column 1.
#
# For instance, if we want to search ("virtual health" OR "mobile health") AND ("public health" OR "health promotion"), we would use query: "virtual+health[tw] OR mobile+health[tw]) AND (public+health[tw] OR health+promotion[tw]".
#
# Note: [tw] is a "Field Tag" helping to search specific fields of the PubMed, it refers to "text words"[1].

# %% [markdown]
# First, let's build the query

# %%
def form_query_term(df):
    '''
    arg: df: dataframe containing a list of terms1 in single column
    return:
        array: containing processed search terms, eg: "mhealth[tw] OR m-health[tw] OR ehealth[tw]"
    '''
    query_arr = []
    tag = "[tw]"

    for term in df:
        #if term == "" or "*" in term:
        if term == "" in term:
            continue
            
        # eg: mhealth or m-health
        if " or " in term:
            or_terms = term.split(" or ")
            for each in or_terms:
               # query_string += each.rstrip().lstrip()
                query_arr.append(each.rstrip().lstrip().replace(" ", "+") + tag)
                
        else:
            query_arr.append(term.rstrip().lstrip().replace(" ", "+") + tag)
            
    return query_arr

# %%
#query_string = "(“mhealth” OR “m-health“ OR “ehealth“ OR “e-health“ OR “virtual health“ OR “mobile health“ OR “online health“ OR “internet-based health“ OR “computer-based health“ OR “health informatics“ OR “social media“ OR “predictive algorithms“ OR “artificial intelligence“ OR “machine learning methods“ OR “big data“ OR “electronic health“ OR “telemedicine“ OR “digit” OR “web”) AND (“public health“ OR “health promotion“ OR “health prevention“ OR “health+protection“ OR “health policy” OR “health determinants“ OR “health evaluation“ OR “health economics“ OR “public health ethics“ OR “risk assessment“ OR “epidemiology“ OR “community health“ OR “emergency preparedness“ OR “emergency response“ OR “health equity“ OR “social justice“ OR “social determinants“ OR “surveillance“) AND “last 20 years”[dp]"
query_string = "(%E2%80%9Cmhealth%E2%80%9D%20OR%20%E2%80%9Cm-health%E2%80%9C%20OR%20%E2%80%9Cehealth%E2%80%9C%20OR%20%E2%80%9Ce-health%E2%80%9C%20OR%20%E2%80%9Cvirtual%20health%E2%80%9C%20OR%20%E2%80%9Cmobile%20health%E2%80%9C%20OR%20%E2%80%9Conline%20health%E2%80%9C%20OR%20%E2%80%9Cinternet-based%20health%E2%80%9C%20OR%20%E2%80%9Ccomputer-based%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20informatics%E2%80%9C%20OR%20%E2%80%9Csocial%20media%E2%80%9C%20OR%20%E2%80%9Cpredictive%20algorithms%E2%80%9C%20OR%20%E2%80%9Cartificial%20intelligence%E2%80%9C%20OR%20%E2%80%9Cmachine%20learning%20methods%E2%80%9C%20OR%20%E2%80%9Cbig%20data%E2%80%9C%20OR%20%E2%80%9Celectronic%20health%E2%80%9C%20OR%20%E2%80%9Ctelemedicine%E2%80%9C%20OR%20%E2%80%9Cdigit%E2%80%9D%20OR%20%E2%80%9Cweb%E2%80%9D)%20AND%20(%E2%80%9Cpublic%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20promotion%E2%80%9C%20OR%20%E2%80%9Chealth%20prevention%E2%80%9C%20OR%20%E2%80%9Chealth+protection%E2%80%9C%20OR%20%E2%80%9Chealth%20policy%E2%80%9D%20OR%20%E2%80%9Chealth%20determinants%E2%80%9C%20OR%20%E2%80%9Chealth%20evaluation%E2%80%9C%20OR%20%E2%80%9Chealth%20economics%E2%80%9C%20OR%20%E2%80%9Cpublic%20health%20ethics%E2%80%9C%20OR%20%E2%80%9Crisk%20assessment%E2%80%9C%20OR%20%E2%80%9Cepidemiology%E2%80%9C%20OR%20%E2%80%9Ccommunity%20health%E2%80%9C%20OR%20%E2%80%9Cemergency%20preparedness%E2%80%9C%20OR%20%E2%80%9Cemergency%20response%E2%80%9C%20OR%20%E2%80%9Chealth%20equity%E2%80%9C%20OR%20%E2%80%9Csocial%20justice%E2%80%9C%20OR%20%E2%80%9Csocial%20determinants%E2%80%9C%20OR%20%E2%80%9Csurveillance%E2%80%9C)%20AND%20%E2%80%9Clast%2020%20years%E2%80%9D[dp]&RetMax=10"
# connector = " " + "OR" + " "
# query_arr_a = form_query_term(search_terms_c1)     
# query_arr_b = form_query_term(search_terms_c2) 
# query_string = "(" + connector.join(query_arr_a) + ")" + " AND " + "(" + connector.join(query_arr_b) + ")"
logger.debug(query_string)
# Out:
# DEBUG:Parsing_Data:(%E2%80%9Cmhealth%E2%80%9D%20OR%20%E2%80%9Cm-health%E2%80%9C%20OR%20%E2%80%9Cehealth%E2%80%9C%20OR%20%E2%80%9Ce-health%E2%80%9C%20OR%20%E2%80%9Cvirtual%20health%E2%80%9C%20OR%20%E2%80%9Cmobile%20health%E2%80%9C%20OR%20%E2%80%9Conline%20health%E2%80%9C%20OR%20%E2%80%9Cinternet-based%20health%E2%80%9C%20OR%20%E2%80%9Ccomputer-based%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20informatics%E2%80%9C%20OR%20%E2%80%9Csocial%20media%E2%80%9C%20OR%20%E2%80%9Cpredictive%20algorithms%E2%80%9C%20OR%20%E2%80%9Cartificial%20intelligence%E2%80%9C%20OR%20%E2%80%9Cmachine%20learning%20methods%E2%80%9C%20OR%20%E2%80%9Cbig%20data%E2%80%9C%20OR%20%E2%80%9Celectronic%20health%E2%80%9C%20OR%20%E2%80%9Ctelemedicine%E2%80%9C%20OR%20%E2%80%9Cdigit%E2%80%9D%20OR%20%E2%80%9Cweb%E2%80%9D)%20AND%20(%E2%80%9Cpublic%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20promotion%E2%80%9C%20OR%20%E2%80%9Chealth%20prevention%E2%80%9C%20OR%20%E2%80%9Chealth+protection%E2%80%9C%20OR%20%E2%80%9Chealth%20policy%E2%80%9D%20OR%20%E2%80%9Chealth%20determinants%E2%80%9C%20OR%20%E2%80%9Chealth%20evaluation%E2%80%9C%20OR%20%E2%80%9Chealth%20economics%E2%80%9C%20OR%20%E2%80%9Cpublic%20health%20ethics%E2%80%9C%20OR%20%E2%80%9Crisk%20assessment%E2%80%9C%20OR%20%E2%80%9Cepidemiology%E2%80%9C%20OR%20%E2%80%9Ccommunity%20health%E2%80%9C%20OR%20%E2%80%9Cemergency%20preparedness%E2%80%9C%20OR%20%E2%80%9Cemergency%20response%E2%80%9C%20OR%20%E2%80%9Chealth%20equity%E2%80%9C%20OR%20%E2%80%9Csocial%20justice%E2%80%9C%20OR%20%E2%80%9Csocial%20determinants%E2%80%9C%20OR%20%E2%80%9Csurveillance%E2%80%9C)%20AND%20%E2%80%9Clast%2020%20years%E2%80%9D[dp]&RetMax=10

# %% [markdown]
# Secondly, Lets extract all the related ids givne the query

# %%
def extract_ids(query_term, return_size=10):
    '''
    args: query_string 
    return: find and set max_return_size 
            return list of related ids
    '''

    ret_max_term = "&RetMax=" + str(return_size)
    
    base_url_key_word = base_url + search_url + query_term + ret_max_term #+ application + email
    
    print(base_url_key_word)
    
    page_kw = urlopen(base_url_key_word)
    soup_kw = BeautifulSoup(page_kw, "xml")
    
    # get text form of everything in the xml file
    # soup_kw.get_text()
    
    return_size = soup_kw.find('Count').text    
    id_list = soup_kw.find_all('Id')
    
    return_ids = []
    for each_id in id_list:
        # print(each_id.text)
        return_ids.append(each_id.text)
    
    return return_size, return_ids

# %%
def id_convert(pmid):
    
    base_url_converter = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"
    api_url = base_url_converter + "?ids=" + sample_pmid + "&format=json"
    #print(api_url)
    response = requests.get(api_url)

    if response.status_code == 200:
        res = json.loads(response.content.decode('utf-8'))
  #print(res)
        if 'pmcid' not in res['records'][0]:
            print("this pm_id is not valid in pmc")
            return None
            
        else:
            pmc_id = res['records'][0]['pmcid']
            print("Corresponding pmcid is: {}".format(pmc_id))
            return pmc_id

# %%
return_size = extract_ids(query_string)[0]
logger.debug("there are {} related papers".format(return_size))
return_ids = extract_ids(query_string, return_size)[1]


    
# save the pmc_list in a file:
# f=open('./pmc_list.txt','w')
# for id in return_ids:
#     f.write(id+'\n')
# f.close()
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=(%E2%80%9Cmhealth%E2%80%9D%20OR%20%E2%80%9Cm-health%E2%80%9C%20OR%20%E2%80%9Cehealth%E2%80%9C%20OR%20%E2%80%9Ce-health%E2%80%9C%20OR%20%E2%80%9Cvirtual%20health%E2%80%9C%20OR%20%E2%80%9Cmobile%20health%E2%80%9C%20OR%20%E2%80%9Conline%20health%E2%80%9C%20OR%20%E2%80%9Cinternet-based%20health%E2%80%9C%20OR%20%E2%80%9Ccomputer-based%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20informatics%E2%80%9C%20OR%20%E2%80%9Csocial%20media%E2%80%9C%20OR%20%E2%80%9Cpredictive%20algorithms%E2%80%9C%20OR%20%E2%80%9Cartificial%20intelligence%E2%80%9C%20OR%20%E2%80%9Cmachine%20learning%20methods%E2%80%9C%20OR%20%E2%80%9Cbig%20data%E2%80%9C%20OR%20%E2%80%9Celectronic%20health%E2%80%9C%20OR%20%E2%80%9Ctelemedicine%E2%80%9C%20OR%20%E2%80%9Cdigit%E2%80%9D%20OR%20%E2%80%9Cweb%E2%80%9D)%20AND%20(%E2%80%9Cpublic%20health%E2%80%9C%20OR%20%E2%80%9Chealth%20promotion%E2%80%9C%20OR%20%E2%80%9Chealth%20prevention%E2%80%9C%20OR%20%E2%80%9Chealth+protection%E2%80%9C%20OR%20%E2%80%9Chealth%20policy%E2%80%9D%20OR%20%E2%80%9Chealth%20determinants%E2%80%9C%20OR%20%E2%80%9Chealth%20evaluation%E2%80%9C%20OR%20%E2%80%9Chealth%20economics%E2%80%9C%20OR%20%E2%80%9Cpublic%20health%20ethics%E2%80%9C%20OR%20%E2%80%9Crisk%20assessment%E2%80%9C%20OR%20%E2%80%9Cepidemiology%E2%80%9C%20OR%20%E2%80%9Ccommunity%20health%E2%80%9C%20OR%20%E2%80%9Cemergency%20preparedness%E2%80%9C%20OR%20%E2%80%9Cemergency%20response%E2%80%9C%20OR%20%E2%80%9Chealth%20equity%E2%80%9C%20OR%20%E2%80%9Csocial%20justice%E2%80%9C%20OR%20%E2%80%9Csocial%20determinants%E2%80%9C%20OR%20%E2%80%9Csurveillance%E2%80%9C)%20AND%20%E2%80%9Clast%2020%20years%E2%80%9D[dp]&RetMax=10&RetMax=10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-bcf81b467b27> in <module>
# ----> 1 return_size = extract_ids(query_string)[0]
#       2 logger.debug("there are {} related papers".format(return_size))
#       3 return_ids = extract_ids(query_string, return_size)[1]
#       4
#       5
#
# <ipython-input-22-d0379ae2964e> in extract_ids(query_term, return_size)
#      13
#      14     page_kw = urlopen(base_url_key_word)
# ---> 15     soup_kw = BeautifulSoup(page_kw, "xml")
#      16
#      17     # get text form of everything in the xml file
#
# NameError: name 'BeautifulSoup' is not defined

# %%
valid_ids = []
for each in return_ids:
    res = id_convert(each)
    if res is not None:
        valid_ids.append(res)

print(len(valid_ids))

# %% [markdown]
# # Extract article information in xml

# %%
return_ids = []
# with open('./pmc_list.txt','r') as f:
#   line = f.read()
#   return_ids.append(line)
# f.close()
with open('./pmc_list.txt','r') as f:
    for line in f:
        return_ids.append(line.strip())
f.close()

# %%
len(return_ids)
#return_ids
# Out:
# 79006

# %%
#sem = threading.Semaphore(3)

def extract_xml(paper_id):
    
    query_id = "&id=" + str(paper_id)
    base_url_content = base_url + fetch_url + query_id
    sem.acquire()
    try:
      response = requests.get(base_url_content)
      with open('./data/{}_paper.xml'.format(paper_id), 'wb') as file:
          file.write(response.content)
      file.close()
    finally:
        sem.release()
    

    # get text form of everything in the xml file
    #soup.get_text()
    
    time.sleep(1)

# %%
def num_cpus():
    try:
        return len(os.sched_getaffinity(0))
    except AttributeError:
        return os.cpu_count()
num_cpus()
# Out:
# 4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from concurrent.futures import ThreadPoolExecutor
import threading
sem = threading.Semaphore(3)
#return_ids = pd.read_csv(DATA_PATH/'ukb10109.csv', chunksize=chunksize, header=0, low_memory=False) # temporarily prevent error when set index later index_col='eid'

# def process(chunk):
#     print("Thread {} Starting".format(threading.currentThread().getName()))
#     try:
#         global arr
#         global label_arr
#         df_combined = pd.DataFrame()
#         for usable_col in numeric_cols:
#             combined_col = None
#             combined_col_name = ''
#             for i, col_name in enumerate(chunk.iloc[:,[int(col) for col in usable_col.columns]]):
#                 if i == 0:
#                     combined_col = chunk[col_name]
#                     combined_col_name = col_name.split('-')[0]
#                 else:
#                     #TODO: reeval the decision: fillna used other columns to fill the first one vs overriding
#                     combined_col = combined_col.fillna(chunk[col_name])
# #             if usable_col.udi=='84':
# #                 import pdb; pdb.set_trace()
#             df_combined[combined_col_name] = combined_col
#         clinical_lock.acquire()
#         df_label = df_clinical.loc[df_combined.eid]
#         clinical_lock.release()
#         lock.acquire()
#         arr.append(df_combined.set_index('eid').values.astype('float'))
#         arr.flush()
#         label_arr.append(df_label.values)
#         label_arr.flush()
#         lock.release()
#     except:
#         print("Unexpected error:", sys.exc_info())
#     print("Thread {} Exiting".format(threading.currentThread().getName()))
#     return True

start = time.time()
# with ThreadPoolExecutor(max_workers=num_cpus()//2) as executor:
with ThreadPoolExecutor(max_workers=3) as executor:
    results = executor.map(extract_xml, return_ids)
#     jobs = (executor.submit(process, chunk) for chunk in df_generator)
print('Total time taken: {}'.format(time.time() - start))

# %%
# for each_id in progress_bar(return_ids):
#     logger.debug("########" + each_id)
#     extract_xml(each_id)
    
start = time.time()
# with ThreadPoolExecutor(max_workers=num_cpus()//2) as executor:
with ThreadPoolExecutor(max_workers=3) as executor:
    results = executor.map(extract_xml, return_ids[:100])
#     jobs = (executor.submit(process, chunk) for chunk in df_generator)
print('Total time taken: {}'.format(time.time() - start))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23984' class='' max='78390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.60% [23984/78390 9:26:03<21:24:04]
#     </div>
# Streaming output truncated to the last 5000 lines.
# DEBUG:Parsing_Data:########6480029
# DEBUG:Parsing_Data:########6479847
# DEBUG:Parsing_Data:########6479610
# DEBUG:Parsing_Data:########6474281
# DEBUG:Parsing_Data:########6467258
# DEBUG:Parsing_Data:########6460312
# DEBUG:Parsing_Data:########6460311
# DEBUG:Parsing_Data:########6460310
# DEBUG:Parsing_Data:########6460309
# DEBUG:Parsing_Data:########6460308
# DEBUG:Parsing_Data:########6280304
# DEBUG:Parsing_Data:########6280301
# DEBUG:Parsing_Data:########6267805
# DEBUG:Parsing_Data:########6266542
# DEBUG:Parsing_Data:########6263706
# DEBUG:Parsing_Data:########6258780
# DEBUG:Parsing_Data:########6258737
# DEBUG:Parsing_Data:########6254750
# DEBUG:Parsing_Data:########6254657
# DEBUG:Parsing_Data:########6253361
# DEBUG:Parsing_Data:########6251012
# DEBUG:Parsing_Data:########6249980
# DEBUG:Parsing_Data:########6249978
# DEBUG:Parsing_Data:########6249928
# DEBUG:Parsing_Data:########6249922
# DEBUG:Parsing_Data:########6249895
# DEBUG:Parsing_Data:########6249871
# DEBUG:Parsing_Data:########6249653
# DEBUG:Parsing_Data:########6248994
# DEBUG:Parsing_Data:########6248974
# DEBUG:Parsing_Data:########6248973
# DEBUG:Parsing_Data:########6248918
# DEBUG:Parsing_Data:########6247700
# DEBUG:Parsing_Data:########6247239
# Buffered data was truncated after reaching the output size limit.

# %%
# Out:
# Mounted at /content/drive/

# %%
# import os
# os. getcwd()
# #!ls
# with open('/content/drive/My Drive/foo.txt', 'w') as f:
#   f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# INFO:root:
# Unfortunately, your original traceback can not be constructed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-56-e67bef50a811>", line 2, in <module>
#     os. getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
# %cd '/content/drive/My Drive/[JOB]\ RA'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# INFO:root:
# Unfortunately, your original traceback can not be constructed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-49-6686a59742b2>", line 1, in <module>
#     get_ipython().magic("cd '/content/drive/My Drive/[JOB]\\ RA/'")
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
#     oldcwd = py3compat.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
# %cd ..
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-40-392013b89fb5>", line 1, in <module>
#     get_ipython().magic('cd ..')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
#     oldcwd = py3compat.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
# %cd '/content/drive/My Drive/'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-fa6c1c65b32e>", line 1, in <module>
#     get_ipython().magic("cd '/content/drive/My Drive/'")
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
#     oldcwd = py3compat.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %% [markdown]
# # TODO
#
# - how to treat sesarch terms, such as :"mhealth or m-health" and "web*"

# %% [markdown]
# # Reference
#
# [1]Search Field Tags:  https://www.nlm.nih.gov/bsd/disted/pubmedtutorial/020_710.html
